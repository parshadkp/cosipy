# %% [markdown]
# # NGC 1068 Case 2 threshold sensitivity: CPL + PL
#
# Scans `norm_nt` at 24 months and selects the lowest tested value with median added-tail ΔTS ≥ 9. The representative seed is selected by median ΔTS, then median recovered `norm_nt`. A matched 3-month companion is saved without a second threshold scan.

# %%
import numpy as np
from IPython.display import display
from agn_fixed_case_sensitivity import (
    load_sed_handoff,
    plot_norm_threshold_ensemble,
    run_norm_threshold_ensemble,
    save_threshold_companion_exposure,
)
# %matplotlib inline
# Out:
# 11:58:12 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=837796;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=102370;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#43\43]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=726774;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=95691;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#65\65]8;;\
#                   will not be available.
# ...

# %%
RESPONSE_PATH = (
    "/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/"
    "COSI/Radio_Quiet_AGN/DC4_Files/"
    "ResponseContinuum.o3.e100_10000.b10log.s10396905069491.m2284."
    "filtered.nonsparse.binnedimaging.imagingresponse.h5"
)
ORIENTATION_PATH = (
    "/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/"
    "COSI/Radio_Quiet_AGN/DC4_Files/"
    "DC4_final_530km_3_month_with_slew_15sbins_GalacticEarth_SAA.fits"
)
BACKGROUND_PATH = (
    "/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/"
    "COSI/Radio_Quiet_AGN/DC4_Files/Background/"
    "Total_DC4_BG_3months_binned_data_filtered_with_SAAcut_withSAAbck_"
    "NGC1068_60deg_fov_cut.hdf5"
)

case = {
    "source_name": "NGC1068",
    "case_tag": "NGC1068_Case2",
    "output_prefix": "NGC1068_Case2_CPL_PL_threshold",
    "description": "NGC 1068 Case 2: thermal CPL Ec=128 keV plus PL tail",
    "file_stem": "ec_128_DC4_COSI_cpl_pl_60_fovCut",
    "comparison": "added_component",
    "longitude_deg": 172.104,
    "latitude_deg": -51.934,
    "fov_cut_deg": 60.0,
    "response_path": RESPONSE_PATH,
    "orientation_path": ORIENTATION_PATH,
    "background_path": BACKGROUND_PATH,
    "fit_pivot_keV": 200.0,
    # Exactly two fits per seed: CPL-only first, followed by one CPL+PL
    # fit initialized from the CPL solution plus the injected tail.
    "fit_strategy": "nested_single_start",
    "primary": {
        "kind": "cpl", "K": 3.1e-1, "pivot_keV": 1.0,
        "cutoff_keV": 128.0, "index": -2.10,
        "fit_index_free": False, "fit_cutoff_free": True,
        "K_min": 1e-8, "K_max": 1e-2,
        "cutoff_min_keV": 10.0, "cutoff_max_keV": 2000.0,
    },
    "secondary": {
        "kind": "pl", "pivot_keV": 200.0, "index": -2.8,
        "fit_index_free": True,
        "K_min": 1e-10, "K_max": 1e-4,
        "index_min": -5.0, "index_max": 1.0, "index_delta": 0.25,
        "normalization": {
            "mode": "flux_ratio", "ratio": 0.42, "energy_keV": 200.0,
        },
    },
}
exposure_months = 24

# Edit this grid when exploring the non-thermal threshold. Every value runs
# n_seeds independent realizations; cached completed values are reused.
norm_nt_grid = np.array([1])
n_seeds = 300
seed_start = 106800
target_delta_ts = 9.0
resume_existing_trials = False

# %%
print(f"=== {exposure_months}-month threshold scan ===")
threshold_result = run_norm_threshold_ensemble(
    case,
    norm_nt_grid,
    n_seeds=n_seeds,
    seed_start=seed_start,
    exposure_months=exposure_months,
    target_delta_ts=target_delta_ts,
    resume_existing_trials=resume_existing_trials,
)
display(threshold_result["threshold_summary"])
display(threshold_result["delta_ts_candidates"][[
    "seed", "delta_ts", "delta_ts_distance_from_median",
    "fit_start_label", "n_successful_starts",
    "fit_secondary_link_ratio",
    "recovered_norm_nt_distance_from_median",
]])

companion_3m_result = save_threshold_companion_exposure(
    threshold_result,
    exposure_months=3,
)
# Out:
# === 24-month threshold scan ===
# Loaded 1060 checkpointed trials from /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/NGC1068_Case2/NGC1068_Case2_CPL_PL_threshold_trials_24months.csv

# %%
fig, axes = plot_norm_threshold_ensemble(threshold_result)
fig.suptitle(f"{case['description']}, {exposure_months} months")

# %%
sed_handoff_24m = load_sed_handoff(threshold_result["manifest_file"])
sed_handoff_3m = load_sed_handoff(companion_3m_result["manifest_file"])
print(24, sed_handoff_24m[0]["median_data_file"])
print(3, sed_handoff_3m[0]["median_data_file"])
