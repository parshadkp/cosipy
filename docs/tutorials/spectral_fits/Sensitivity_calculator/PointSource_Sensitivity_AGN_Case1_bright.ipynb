# %% [markdown]
# # NGC 4151 Case 1: bright thermal state
#
# Runs 100 Poisson realizations at both 3 and 24 months. For each exposure, it selects the realization closest to the median source-detection TS; equal-distance candidates are ranked by closeness to the median recovered cutoff energy, then by seed.

# %%
from IPython.display import display
from agn_fixed_case_sensitivity import (
    load_sed_handoff,
    plot_fixed_case_ensemble,
    run_fixed_case_ensemble,
)
# %matplotlib inline
# Out:
# 17:30:20 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=90683;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=690069;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#43\43]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=656796;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=493058;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#65\65]8;;\
#                   will not be available.
# 17:30:21 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=974416;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=473803;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
# 17:30:22 INFO      Starting 3ML!                                                                     ]8;id=468315;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=559722;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#44\44]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=866613;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=40476;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#45\45]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=136710;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=700918;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#46\46]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=796202;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=24525;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#47\47]8;;\
#          WARNING   ROOT minimizer not available                                                ]8;id=364761;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=845137;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1208\1208]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=251084;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=617113;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1218\1218]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=343753;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=716264;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1228\1228]8;;\
# 17:30:23 WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=959548;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=842415;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#126\126]8;;\
#                   software installed and configured?
# 17:30:24 WARNING   No fermitools installed                                              ]8;id=183265;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=635669;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=367927;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=634084;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=509229;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=470928;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=785905;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=332392;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML

# %%
case = {
    "case_tag": "Case1_bright",
    "output_prefix": "NGC4151_bright_TH",
    "description": "Case 1: bright thermal state",
    "file_stem": "ec_264_DC4_COSI_bright_60_fovCut",
    "comparison": "source_detection",
    "longitude_deg": 155.077, "latitude_deg": 75.063, "fov_cut_deg": 60.0,
    "fit_pivot_keV": 200.0,
    "primary": {"kind": "cpl", "K": 0.15, "pivot_keV": 1.0, "cutoff_keV": 264.0, "index": -1.71, "fit_index_free": True, "fit_cutoff_free": True},
}
exposure_months_list = (3, 24)
n_seeds = 300
seed_start = 4100
target_delta_ts = 9.0
resume_existing_trials = True

# %%
results = {}
for exposure_months in exposure_months_list:
    print(f"\n=== {exposure_months}-month ensemble ===")
    results[exposure_months] = run_fixed_case_ensemble(
        case, n_seeds=n_seeds, seed_start=seed_start,
        exposure_months=exposure_months, target_delta_ts=target_delta_ts,
        resume_existing_trials=resume_existing_trials,
    )
    display(results[exposure_months]["summary"])
    display(results[exposure_months]["delta_ts_candidates"][[
        "seed", "delta_ts", "delta_ts_distance_from_median",
        "fit_primary_cutoff_keV",
        "recovered_cutoff_keV_distance_from_median",
    ]])
# Out:
# === 3-month ensemble ===
# Loaded 100 checkpointed trials from /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_bright_TH_trials_3months.csv
# Median source detection TS: 880.370
# Central 68% range: 683.773-1076.607
# Fraction >= 9: 1.000
# Median recovered_cutoff_keV: 257.74
# Delta-TS-primary candidates: 2
# Representative seed: 4137
# Representative statistic: 877.305
# Representative recovered_cutoff_keV: 277.24
# Saved median data: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_plus_bkg_ec_264_DC4_COSI_bright_60_fovCut_3months_medianSeed_4137.hdf5
# Saved manifest: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_bright_TH_median_realization_3months.json
#        case_tag        comparison  exposure_months  n_requested_seeds  \
# 0  Case1_bright  source_detection                3                100
#
#    n_successful_fits  median_delta_ts  delta_ts_q16  delta_ts_q84  \
# 0                100       880.370339    683.773327    1076.60676
#
#    target_delta_ts  fraction_delta_ts_ge_target  \
# 0              9.0                          1.0
#
#   representative_secondary_criterion  median_recovered_cutoff_keV  \
# 0               recovered_cutoff_keV                   257.743371
#
#    representative_seed  representative_delta_ts  \
# 0                 4137               877.305224
#
#    representative_recovered_cutoff_keV
# 0                           277.241127
#     seed    delta_ts  delta_ts_distance_from_median  fit_primary_cutoff_keV  \
# 37  4137  877.305224                       3.065115              277.241127
# 85  4185  883.435454                       3.065115              153.234262
#
#     recovered_cutoff_keV_distance_from_median
# 37                                  19.497756
# 85                                 104.509109
# === 24-month ensemble ===
# Loaded 100 checkpointed trials from /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_bright_TH_trials_24months.csv
# Median source detection TS: 7097.978
# Central 68% range: 6681.595-7696.494
# Fraction >= 9: 1.000
# Median recovered_cutoff_keV: 264.73
# Delta-TS-primary candidates: 2
# Representative seed: 4167
# Representative statistic: 7096.471
# Representative recovered_cutoff_keV: 258.98
# Saved median data: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_plus_bkg_ec_264_DC4_COSI_bright_60_fovCut_24months_medianSeed_4167.hdf5
# Saved manifest: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_bright_TH_median_realization_24months.json
#        case_tag        comparison  exposure_months  n_requested_seeds  \
# 0  Case1_bright  source_detection               24                100
#
#    n_successful_fits  median_delta_ts  delta_ts_q16  delta_ts_q84  \
# 0                100       7097.97783   6681.594893   7696.494045
#
#    target_delta_ts  fraction_delta_ts_ge_target  \
# 0              9.0                          1.0
#
#   representative_secondary_criterion  median_recovered_cutoff_keV  \
# 0               recovered_cutoff_keV                   264.728765
#
#    representative_seed  representative_delta_ts  \
# 0                 4167              7096.470814
#
#    representative_recovered_cutoff_keV
# 0                            258.97936
#     seed     delta_ts  delta_ts_distance_from_median  fit_primary_cutoff_keV  \
# 29  4129  7099.484847                       1.507017              295.304782
# 67  4167  7096.470814                       1.507017              258.979360
#
#     recovered_cutoff_keV_distance_from_median
# 29                                  30.576017
# 67                                   5.749406

# %%
for exposure_months in exposure_months_list:
    fig, ax = plot_fixed_case_ensemble(results[exposure_months])
    ax.set_title(f"{case['description']}, {exposure_months} months")

# %%
sed_handoffs = {}
for exposure_months in exposure_months_list:
    sed_handoffs[exposure_months] = load_sed_handoff(results[exposure_months]["manifest_file"])
    print(exposure_months, sed_handoffs[exposure_months][0]["median_data_file"])
# Out:
# 3 /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_plus_bkg_ec_264_DC4_COSI_bright_60_fovCut_3months_medianSeed_4137.hdf5
# 24 /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_bright/NGC4151_plus_bkg_ec_264_DC4_COSI_bright_60_fovCut_24months_medianSeed_4167.hdf5
