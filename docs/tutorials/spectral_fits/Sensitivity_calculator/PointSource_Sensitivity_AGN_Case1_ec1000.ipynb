# %% [markdown]
# # NGC 4151 Case 1: thermal CPL, Ec=1000 keV
#
# Runs 100 Poisson realizations at both 3 and 24 months. For each exposure, it selects the realization closest to the median source-detection TS; equal-distance candidates are ranked by closeness to the median recovered cutoff energy, then by seed.

# %%
from IPython.display import display
from agn_fixed_case_sensitivity import (
    load_sed_handoff,
    plot_fixed_case_ensemble,
    run_fixed_case_ensemble,
)
# %matplotlib inline
# Out:
# 17:29:23 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=912030;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=948875;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#43\43]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=256580;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=350127;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#65\65]8;;\
#                   will not be available.
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=299555;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=630055;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
# 17:29:24 INFO      Starting 3ML!                                                                     ]8;id=306281;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=950839;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#44\44]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=428774;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=921097;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#45\45]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=299974;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=248537;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#46\46]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=581216;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7394;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#47\47]8;;\
#          WARNING   ROOT minimizer not available                                                ]8;id=813505;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=182174;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1208\1208]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=889621;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=280688;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1218\1218]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=597372;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=605993;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1228\1228]8;;\
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=657272;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=716833;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#126\126]8;;\
#                   software installed and configured?
# 17:29:25 WARNING   No fermitools installed                                              ]8;id=815595;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=226293;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=283083;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=165963;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=32586;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=832351;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=495008;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=262493;file:///Users/parshadkp/.pyenv/versions/cosipy312/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML

# %%
case = {
    "case_tag": "Case1_ec1000",
    "output_prefix": "NGC4151_ec1000_TH",
    "description": "Case 1: thermal CPL, Ec=1000 keV",
    "file_stem": "ec_1000_DC4_COSI_cpl_60_fovCut",
    "comparison": "source_detection",
    "longitude_deg": 155.077, "latitude_deg": 75.063, "fov_cut_deg": 60.0,
    "fit_pivot_keV": 200.0,
    "primary": {"kind": "cpl", "K": 0.15, "pivot_keV": 1.0, "cutoff_keV": 1000.0, "index": -1.75, "fit_index_free": True, "fit_cutoff_free": True},
}
exposure_months_list = (3, 24)
n_seeds = 300
seed_start = 4100
target_delta_ts = 9.0
resume_existing_trials = True

# %%
results = {}
for exposure_months in exposure_months_list:
    print(f"\n=== {exposure_months}-month ensemble ===")
    results[exposure_months] = run_fixed_case_ensemble(
        case, n_seeds=n_seeds, seed_start=seed_start,
        exposure_months=exposure_months, target_delta_ts=target_delta_ts,
        resume_existing_trials=resume_existing_trials,
    )
    display(results[exposure_months]["summary"])
    display(results[exposure_months]["delta_ts_candidates"][[
        "seed", "delta_ts", "delta_ts_distance_from_median",
        "fit_primary_cutoff_keV",
        "recovered_cutoff_keV_distance_from_median",
    ]])
# Out:
# === 3-month ensemble ===
# Loaded 100 checkpointed trials from /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_ec1000_TH_trials_3months.csv
# Median source detection TS: 2074.048
# Central 68% range: 1809.048-2365.153
# Fraction >= 9: 1.000
# Median recovered_cutoff_keV: 1030.7
# Delta-TS-primary candidates: 2
# Representative seed: 4124
# Representative statistic: 2084.506
# Representative recovered_cutoff_keV: 1103.7
# Saved median data: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_plus_bkg_ec_1000_DC4_COSI_cpl_60_fovCut_3months_medianSeed_4124.hdf5
# Saved manifest: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_ec1000_TH_median_realization_3months.json
#        case_tag        comparison  exposure_months  n_requested_seeds  \
# 0  Case1_ec1000  source_detection                3                100
#
#    n_successful_fits  median_delta_ts  delta_ts_q16  delta_ts_q84  \
# 0                100      2074.047959   1809.048032   2365.152633
#
#    target_delta_ts  fraction_delta_ts_ge_target  \
# 0              9.0                          1.0
#
#   representative_secondary_criterion  median_recovered_cutoff_keV  \
# 0               recovered_cutoff_keV                  1030.690777
#
#    representative_seed  representative_delta_ts  \
# 0                 4124              2084.505717
#
#    representative_recovered_cutoff_keV
# 0                          1103.660417
#     seed     delta_ts  delta_ts_distance_from_median  fit_primary_cutoff_keV  \
# 24  4124  2084.505717                      10.457758             1103.660417
# 79  4179  2063.590201                      10.457758             1441.213925
#
#     recovered_cutoff_keV_distance_from_median
# 24                                  72.969640
# 79                                 410.523148
# === 24-month ensemble ===
# Loaded 100 checkpointed trials from /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_ec1000_TH_trials_24months.csv
# Median source detection TS: 16604.788
# Central 68% range: 15923.884-17267.649
# Fraction >= 9: 1.000
# Median recovered_cutoff_keV: 999.07
# Delta-TS-primary candidates: 2
# Representative seed: 4106
# Representative statistic: 16629.910
# Representative recovered_cutoff_keV: 972.37
# Saved median data: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_plus_bkg_ec_1000_DC4_COSI_cpl_60_fovCut_24months_medianSeed_4106.hdf5
# Saved manifest: /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_ec1000_TH_median_realization_24months.json
#        case_tag        comparison  exposure_months  n_requested_seeds  \
# 0  Case1_ec1000  source_detection               24                100
#
#    n_successful_fits  median_delta_ts  delta_ts_q16  delta_ts_q84  \
# 0                100     16604.788004   15923.88394  17267.648643
#
#    target_delta_ts  fraction_delta_ts_ge_target  \
# 0              9.0                          1.0
#
#   representative_secondary_criterion  median_recovered_cutoff_keV  \
# 0               recovered_cutoff_keV                   999.068558
#
#    representative_seed  representative_delta_ts  \
# 0                 4106             16629.910217
#
#    representative_recovered_cutoff_keV
# 0                           972.365914
#     seed      delta_ts  delta_ts_distance_from_median  fit_primary_cutoff_keV  \
# 6   4106  16629.910217                      25.122213              972.365914
# 92  4192  16579.665791                      25.122213              791.077824
#
#     recovered_cutoff_keV_distance_from_median
# 6                                   26.702644
# 92                                 207.990734

# %%
for exposure_months in exposure_months_list:
    fig, ax = plot_fixed_case_ensemble(results[exposure_months])
    ax.set_title(f"{case['description']}, {exposure_months} months")

# %%
sed_handoffs = {}
for exposure_months in exposure_months_list:
    sed_handoffs[exposure_months] = load_sed_handoff(results[exposure_months]["manifest_file"])
    print(exposure_months, sed_handoffs[exposure_months][0]["median_data_file"])
# Out:
# 3 /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_plus_bkg_ec_1000_DC4_COSI_cpl_60_fovCut_3months_medianSeed_4124.hdf5
# 24 /Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/Radio_Quiet_AGN/GammaRay/Paper_Models/Fluctuate_True/Sensitivity_Ensemble/Case1_ec1000/NGC4151_plus_bkg_ec_1000_DC4_COSI_cpl_60_fovCut_24months_medianSeed_4106.hdf5
