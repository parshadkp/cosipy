# %% [markdown]
# # Spectral fitting example (AGN)

# %% [markdown]
# **To run this, you need the following files, which can be downloaded using the first few cells of this notebook:**
# - orientation file (20280301_3_month_with_orbital_info.ori)
# - binned data (NGC4151_ec200_bkg_binned_data.hdf5, NGC4151_ec200_binned_data.hdf5, & bkg_binned_data.hdf5)
# - detector response (SMEXv12.Continuum.HEALPixO3_10bins_log_flat.binnedimaging.imagingresponse.nonsparse_nside8.area.good_chunks_unzip.h5.zip)
#
# **The binned data are simulations of the NGC4151_ec200 Nebula and albedo photon background produced using the COSI SMEX mass model. The detector response needs to be unzipped before running the notebook.**

# %% [markdown]
# This notebook fits the spectrum of a NGC4151_ec200 simulated using MEGAlib and combined with background.
#
# [3ML](https://threeml.readthedocs.io/) is a high-level interface that allows multiple datasets from different instruments to be used coherently to fit the parameters of source model. A source model typically consists of a list of sources with parametrized spectral shapes, sky locations and, for extended sources, shape. Polarization is also possible. A "coherent" analysis, in this context, means that the source model parameters are fitted using all available datasets simultanously, rather than performing individual fits and finding a well-suited common model a posteriori.
#
# In order for a dataset to be included in 3ML, each instrument needs to provide a "plugin". Each plugin is responsible for reading the data, convolving the source model (provided by 3ML) with the instrument response, and returning a likelihood. In our case, we'll compute a binned Poisson likelihood:
#
# $$
# \log \mathcal{L}(\mathbf{x}) = \sum_i \log \frac{\lambda_i(\mathbf{x})^{d_i} \exp (-\lambda_i)}{d_i!}
# $$
#
# where $d_i$ are the counts on each bin and $\lambda_i$ are the expected counts given a source model with parameters $\mathbf{x}$.
#
# In this example, we will fit a single point source with a known location. We'll assume the background is known and fixed up to a scaling factor. Finally, we will fit a Band function:
#
# $$
# f(x) = K \begin{cases} \left(\frac{x}{E_{piv}}\right)^{\alpha} \exp \left(-\frac{(2+\alpha)
#        * x}{x_{p}}\right) & x \leq (\alpha-\beta) \frac{x_{p}}{(\alpha+2)} \\ \left(\frac{x}{E_{piv}}\right)^{\beta}
#        * \exp (\beta-\alpha)\left[\frac{(\alpha-\beta) x_{p}}{E_{piv}(2+\alpha)}\right]^{\alpha-\beta}
#        * &x>(\alpha-\beta) \frac{x_{p}}{(\alpha+2)} \end{cases}
# $$
#
# where $K$ (normalization), $\alpha$ & $\beta$ (spectral indeces), and $x_p$ (peak energy) are the free parameters, while $E_{piv}$ is the pivot energy which is fixed (and arbitrary).
#
# Considering these assumptions:
#
# $$
# \lambda_i(\mathbf{x}) = B*b_i + s_i(\mathbf{x})
# $$
#
# where $B*b_i$ are the estimated counts due to background in each bin with $B$ the amplitude and $b_i$ the shape of the background, and $s_i$ are the corresponding expected counts from the source, the goal is then to find the values of $\mathbf{x} = [K, \alpha, \beta, x_p]$ and $B$ that maximize $\mathcal{L}$. These are the best estimations of the parameters.
#
# The final module needs to also fit the time-dependent background, handle multiple point-like and extended sources, as well as all the spectral models supported by 3ML. Eventually, it will also fit the polarization angle. However, this simple example already contains all the necessary pieces to do a fit.

# %%
from cosipy import COSILike, test_data, BinnedData
from cosipy.spacecraftfile import SpacecraftFile
from cosipy.response.FullDetectorResponse import FullDetectorResponse
from cosipy.util import fetch_wasabi_file
from histpy import Histogram

from scoords import SpacecraftFrame

from astropy.time import Time
import astropy.units as u
from astropy.coordinates import SkyCoord, Galactic

import numpy as np
import matplotlib.pyplot as plt

from threeML import *
from threeML.io.package_data import get_path_of_data_file
from threeML.io.logging import silence_console_log
from astromodels import Parameter

from jupyterthemes import jtplot
jtplot.style(context="talk", fscale=1, ticks=True, grid=False)
set_threeML_style()
silence_warnings()


from pathlib import Path

import os


# %matplotlib inline
# Out:
# /Users/parshadkp/Software/MEGAlib/external/root_v6.36.2/etc/cling/std_darwin.modulemap:8:63: error: header '__type_traits/add_const.h' not found
#     module add_const                                 { header "__type_traits/add_const.h" }
#                                                               ^
# input_line_1:1:10: note: submodule of top-level module 'std' implicitly imported here
# #include <new>
#          ^
# Warning in cling::IncrementalParser::CheckABICompatibility():
#   Failed to extract C++ standard library version.
# Warning in cling::IncrementalParser::CheckABICompatibility():
#   Possible C++ standard library mismatch, compiled with _LIBCPP_ABI_VERSION '1'
#   Extraction of runtime standard library version was: ''
# 20:27:37 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=43071;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=997730;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py#47\47]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=331669;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=658497;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py#68\68]8;;\
#                   will not be available.
# 20:27:38 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=239263;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=290819;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
#          INFO      Starting 3ML!                                                                     ]8;id=297947;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=576159;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#39\39]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=323605;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=407248;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=51023;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=67991;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#41\41]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=790506;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=322359;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#44\44]8;;\
# 20:27:38 WARNING   ROOT minimizer not available                                                ]8;id=826630;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=16011;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1345\1345]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=163429;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=825077;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=762831;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=739785;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
#          WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=246069;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=372871;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=728284;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=774114;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=146040;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=242098;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   No fermitools installed                                              ]8;id=991619;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=860269;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=34565;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=67587;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=880603;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=569269;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=149136;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=665934;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %% [markdown]
# ## Download and read in binned data

# %% [markdown]
# Define the path to the directory containing the data, detector response, orientation file, and yaml files if they have already been downloaded, or the directory to download the files into

# %%
data_path = Path("/Users/parshadkp/Software/COSI_Data/")

# %% [markdown]
# Read in the spacecraft orientation file

# %%
sc_orientation = SpacecraftFile.parse_from_file(data_path / "DC2_Files/20280301_3_month_with_orbital_info.ori")

# %%
dr = str(data_path / "DC2_Files/SMEXv12.Continuum.HEALPixO3_10bins_log_flat.binnedimaging.imagingresponse.nonsparse_nside8.area.good_chunks_unzip.h5") # path to detector response

# %% [markdown]
# Download the orientation file (684.38 MB)

# %%
fetch_wasabi_file('COSI-SMEX/DC2/Data/Orientation/20280301_3_month_with_orbital_info.ori', output=str(data_path / '20280301_3_month_with_orbital_info.ori'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 fetch_wasabi_file('COSI-SMEX/DC2/Data/Orientation/20280301_3_month_with_orbital_info.ori', output=str(data_path / '20280301_3_month_with_orbital_info.ori'))
#
# File ~/Software/cosipy/cosipy/util/data_fetching.py:38, in fetch_wasabi_file(file, output, override, bucket, endpoint, access_key, secret_key)
#      24 def fetch_wasabi_file(file,
#      25                       output = None,
#      26                       overwrite = False,
#    (...)
#      32                       access_key = 'GBAL6XATQZNRV3GFH9Y4',
#      33                       secret_key = 'GToOczY5hGX3sketNO2fUwiq4DJoewzIgvTCHoOv'):
#      34     """
#      35     Download a file from COSI's Wasabi acccount.
#      36
#      37     Parameters
# ---> 38     ----------
#      39     file : str
#      40         Full path to file in Wasabi
#      41     output : str,  optional
#      42         Full path to the downloaded file in the local system. By default it will use
#      43         the current directory and the same file name as the input file.
#      44     overwrite: bool, optional
#      45         Whether to overwrite the file or throw an error if the file already exists
#      46         and has as different checksum. If the file exists but has the same checksum
#      47         it will always throw a warning and skip the file.
#      48     unzip: bool, optional
#      49         Uncompress a .gz or .zip file.
#      50     unzip_output: str, Path, optional
#      51         Path to unzipped output, if different from output without .gz or .zip
#      52     checksum: str
#      53         Expected MD5 sum (hex string).
#      54         The download will be skipped if the output already exists with the correct checksum.
#      55         If the output file already exists but has the wrong checksum, and overwrite=False,
#      56         then it will throw an error.
#      57         If unzip=True, provide the checksum of the unzipped file.
#      58         If checksum is not provided and unzip=False, we will attempt to obtain the
#      59         query Wasabi's ETag for the file.
#      60         Providing a checksum prevents connecting to Wasabi altogether, and therefore is
#      61         recommended for verifying files when a network connection is not available.
#      62     bucket : str, optional
#      63         Passed to aws --bucket option
#      64     endpoint : str, optional
#      65         Passed to aws --endpoint-url option
#      66     access_key : str, optional
#      67         AWS_ACCESS_KEY_ID
#      68     secret_key : str, optional
#      69         AWS_SECRET_ACCESS_KEY
#      70     """
#      72     s3 = boto3.client('s3',
#      73                       endpoint_url=endpoint,
#      74                       aws_access_key_id=access_key,
#      75                       aws_secret_access_key=secret_key)
#      77     if output is None:
#
# RuntimeError: File /Users/parshadkp/Software/COSI_Data/DC2_Files/20280301_3_month_with_orbital_info.ori already exists.

# %% [markdown]
# Download the binned background data (89.10 MB)

# %%
fetch_wasabi_file('COSI-SMEX/cosipy_tutorials/crab_spectral_fit_galactic_frame/bkg_binned_data.hdf5', output=str(data_path / 'bkg_binned_data.hdf5'))
# Out:
# {
#     "AcceptRanges": "bytes",
#     "LastModified": "Tue, 28 Nov 2023 23:55:11 GMT",
#     "ContentLength": 93427437,
#     "ETag": "\"54221d8556eb4ef520ef61da8083e7f4\"",
#     "ContentType": "application/octet-stream",
#     "Metadata": {}
# }

# %% [markdown]
# Download the response file (839.62 MB). This needs to be unzipped before running the rest of the notebook

# %%
fetch_wasabi_file('COSI-SMEX/develop/Data/Responses/SMEXv12.Continuum.HEALPixO3_10bins_log_flat.binnedimaging.imagingresponse.h5', output=str(data_path / 'SMEXv12.Continuum.HEALPixO3_10bins_log_flat.binnedimaging.imagingresponse.h5'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 fetch_wasabi_file('COSI-SMEX/develop/Data/Responses/SMEXv12.Continuum.HEALPixO3_10bins_log_flat.binnedimaging.imagingresponse.h5', output=str(data_path / 'SMEXv12.Continuum.HEALPixO3_10bins_log_flat.binnedimaging.imagingresponse.h5'), checksum = 'eb72400a1279325e9404110f909c7785')
#
# TypeError: fetch_wasabi_file() got an unexpected keyword argument 'checksum'

# %% [markdown]
# # XRay Analysis

# %% [markdown]
# ## BAT Analysis

# %%
bat_rsp = "/Users/parshadkp/Software/COSI_Data/AGN_Data/XRay/swiftbat_survey_full.rsp"
bat_pha = "/Users/parshadkp/Software/COSI_Data/AGN_Data/XRay/SWIFT_J1210.5+3924_resp.pha"

bat = OGIPLike("BAT", observation=bat_pha, response=bat_rsp)

bat.set_active_measurements("40-200")
bat.view_count_spectrum()
# Out:
# 20:27:55 INFO      Auto-probed noise models:                                                    ]8;id=414382;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=981474;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#490\490]8;;\
#          INFO      - observation: gaussian                                                      ]8;id=692297;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=837925;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#491\491]8;;\
#          INFO      - background: None                                                           ]8;id=414816;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=990564;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#492\492]8;;\
#          INFO      Range 40-200 translates to channels 3-8                                     ]8;id=325499;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=606209;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#1247\1247]8;;\
# WARNING UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.

# %%
# l=155.07
# b=75.06

# Give it some harsher initial guesses
K = 1 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
xc = 85. * u.keV
index = -2.5

spectrum_bat = Cutoff_powerlaw()

spectrum_bat.K.value = K.value
spectrum_bat.piv.value = piv.value
spectrum_bat.xc.value = xc.value
spectrum_bat.index.value = index

# #Working parameters
# spectrum_bat.K.min_value = 0.10
# spectrum_bat.K.max_value = 0.17
# spectrum_bat.xc.min_value = 180
# spectrum_bat.xc.max_value = 210
# spectrum_bat.index.min_value = -2.
# spectrum_bat.index.max_value = -1.60

# # Harsher Parameters
spectrum_bat.K.min_value = 1e-4
spectrum_bat.K.max_value = 1e2
spectrum_bat.xc.min_value = 80 # keep these relatively the same
spectrum_bat.xc.max_value = 10000
spectrum_bat.index.min_value = -3.5 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum_bat.index.max_value = 1

spectrum_bat.K.delta = 5e-5
spectrum_bat.xc.delta = 10
spectrum_bat.index.delta = 5e-1

spectrum_bat.K.unit = K.unit
spectrum_bat.piv.unit = piv.unit
spectrum_bat.xc.unit = xc.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum_bat(energy_grid)))
# ax.loglog(energy_grid, spectrum_bat(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source_bat = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = 0,                        # Longitude (deg)
                     b = 0,                        # Latitude (deg)
                     spectral_shape = spectrum_bat)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model_bat = Model(source_bat)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# %%
data_list = DataList(bat)

jl_no_eac = JointLikelihood(model_bat, data_list)

jl_no_eac.fit()
# Out:
# 20:17:57 INFO      set the minimizer to minuit                                             ]8;id=392725;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=408489;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py#1046\1046]8;;\
# Best fit values:
#                                                                result  \
# parameter
# source.spectrum.main.Cutoff_powerlaw.K          (1.5 -1.2 +5) x 10^-1
# source.spectrum.main.Cutoff_powerlaw.index             -1.58 +/- 0.10
# source.spectrum.main.Cutoff_powerlaw.xc     (1.35 -0.27 +0.33) x 10^2
# cons_BAT                                            (3 +/- 4) x 10^-1
#
#                                                        unit
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
# source.spectrum.main.Cutoff_powerlaw.index
# source.spectrum.main.Cutoff_powerlaw.xc                 keV
# cons_BAT
# Correlation matrix:
#  1.00 -0.24  0.24 -0.98
# -0.24  1.00 -0.99  0.02
#  0.24 -0.99  1.00 -0.02
# -0.98  0.02 -0.02  1.00
# Values of -log(likelihood) at the minimum:
#        -log(likelihood)
# BAT            0.000011
# total          0.000011
# Values of statistical measures:
#      statistical measures
# AIC            -11.999978
# BIC              4.394471
# (                                                 value  negative_error  \
#  source.spectrum.main.Cutoff_powerlaw.K        0.153357       -0.128838
#  source.spectrum.main.Cutoff_powerlaw.index   -1.575687       -0.098768
#  source.spectrum.main.Cutoff_powerlaw.xc     135.311103      -26.233212
#  cons_BAT                                      0.273262        0.013385
#
#                                              positive_error      error  \
#  source.spectrum.main.Cutoff_powerlaw.K           -0.004334   0.062252
#  source.spectrum.main.Cutoff_powerlaw.index        0.097942   0.098355
#  source.spectrum.main.Cutoff_powerlaw.xc          33.843122  30.038167
#  cons_BAT                                          0.483562   0.248473
#
#                                                         unit
#  source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
#  source.spectrum.main.Cutoff_powerlaw.index
#  source.spectrum.main.Cutoff_powerlaw.xc                 keV
#  cons_BAT                                                     ,
#         -log(likelihood)
#  BAT            0.000011
#  total          0.000011)

# %%
threeML_config.plugins.ogip.fit_plot.model_cmap = "Set1"
threeML_config.plugins.ogip.fit_plot.n_colors = 3
display_spectrum_model_counts(
    jl_no_eac,
    data_colors=["grey", "k", "k"],
    show_background=False,
    source_only=True,
)

# %%
plot_spectra(jl_no_eac.results, flux_unit="erg2/(keV s cm2)")
# Out:
# processing MLE analyses:   0%|          | 0/1 [00:00<?, ?it/s]
# Propagating errors:   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# ## NuStar Analysis

# %%
# Use the NuSTAR PHA, RMF, and ARF files
nustar_fpma = OGIPLike("nustar_fpma", observation=data_path/"AGN_Data/XRay/nu60001111005A01_sr.pha", background=data_path/"AGN_Data/XRay/nu60001111005A01_bk.pha", response=data_path/"AGN_Data/XRay/nu60001111005A01_sr.rmf", arf_file=data_path/"AGN_Data/XRay/nu60001111005A01_sr.arf")

nustar_fpma.set_active_measurements("20-79")
nustar_fpma.view_count_spectrum()
# Out:
# 20:28:03 INFO      Auto-probed noise models:                                                    ]8;id=889840;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=944661;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#490\490]8;;\
#          INFO      - observation: poisson                                                       ]8;id=171638;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=22845;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#491\491]8;;\
#          INFO      - background: poisson                                                        ]8;id=33066;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=373800;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#492\492]8;;\
#          INFO      Range 20-79 translates to channels 459-1934                                 ]8;id=808684;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=876121;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#1247\1247]8;;\

# %%
nustar_fpmb = OGIPLike("nustar_fpmb", observation=data_path/"AGN_Data/XRay/nu60001111005B01_sr.pha", background=data_path/"AGN_Data/XRay/nu60001111005B01_bk.pha", response=data_path/"AGN_Data/XRay/nu60001111005B01_sr.rmf", arf_file=data_path/"AGN_Data/XRay/nu60001111005B01_sr.arf")
nustar_fpmb.set_active_measurements("20-79")
nustar_fpmb.view_count_spectrum()
# Out:
# 20:28:10 INFO      Auto-probed noise models:                                                    ]8;id=677688;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=283503;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#490\490]8;;\
#          INFO      - observation: poisson                                                       ]8;id=481787;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=956166;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#491\491]8;;\
#          INFO      - background: poisson                                                        ]8;id=111388;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=456905;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#492\492]8;;\
#          INFO      Range 20-79 translates to channels 459-1934                                 ]8;id=255376;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=146294;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#1247\1247]8;;\

# %%
# l=155.07
# b=75.06

# Give it some harsher initial guesses
K = 1 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
xc = 10. * u.keV
index = -2.5

spectrum_nustar = Cutoff_powerlaw()

spectrum_nustar.K.value = K.value
spectrum_nustar.piv.value = piv.value
spectrum_nustar.xc.value = xc.value
spectrum_nustar.index.value = index

# #Working parameters
# spectrum_nustar.K.min_value = 0.10
# spectrum_nustar.K.max_value = 0.17
# spectrum_nustar.xc.min_value = 180
# spectrum_nustar.xc.max_value = 210
# spectrum_nustar.index.min_value = -2.
# spectrum_nustar.index.max_value = -1.60

# # Harsher Parameters
spectrum_nustar.K.min_value = 1e-4
spectrum_nustar.K.max_value = 1e2
spectrum_nustar.xc.min_value = 1 # keep these relatively the same
spectrum_nustar.xc.max_value = 50000
spectrum_nustar.index.min_value = -3.5 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum_nustar.index.max_value = 1

spectrum_nustar.K.delta = 5e-5
spectrum_nustar.xc.delta = 1
spectrum_nustar.index.delta = 5e-1

spectrum_nustar.K.unit = K.unit
spectrum_nustar.piv.unit = piv.unit
spectrum_nustar.xc.unit = xc.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum_nustar(energy_grid)))
# ax.loglog(energy_grid, spectrum_nustar(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source_nustar = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = 0,                        # Longitude (deg)
                     b = 0,                        # Latitude (deg)
                     spectral_shape = spectrum_nustar)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model_nustar = Model(source_nustar)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# %% [markdown]
# ### Simple Powerlaw

# %%
l=155.07
b=75.06

# Give it some harsher initial guesses
K = 1 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
# xc = 1000. * u.keV
index = -2

spectrum_nustar = Powerlaw()

spectrum_nustar.K.value = K.value
spectrum_nustar.piv.value = piv.value
spectrum_nustar.index.value = index

# # Harsher Parameters
spectrum_nustar.K.min_value = 1e-4
spectrum_nustar.K.max_value = 12
spectrum_nustar.index.min_value = -3.5 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum_nustar.index.max_value = 1

spectrum_nustar.K.delta = 0.1
spectrum_nustar.index.delta = 1e-1

spectrum_nustar.K.unit = K.unit
spectrum_nustar.piv.unit = piv.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum(energy_grid)))
# ax.loglog(energy_grid, spectrum(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source_nustar = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = l,                        # Longitude (deg)
                     b = b,                        # Latitude (deg)
                     spectral_shape = spectrum_nustar)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model_nustar = Model(source_nustar)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# %%
# Put them in a DataList
nustar_fpmb.use_effective_area_correction(0.2, 1.8)
data_list_nustar = DataList(nustar_fpma, nustar_fpmb)
# data_list_nustar = DataList(nustar_fpma)

jl_no_eac_nustar = JointLikelihood(model_nustar, data_list_nustar)

jl_no_eac_nustar.fit()
# Out:
# 15:50:04 INFO      nustar_fpmb is using effective area correction (between 0.2 and 1.8)        ]8;id=234610;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=958551;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#2279\2279]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=469724;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=3643;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py#1046\1046]8;;\
# Best fit values:
#                                                                 result  \
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      (2.65 -0.18 +0.20) x 10^-2
# source.spectrum.main.Cutoff_powerlaw.index            -1.319 +/- 0.023
# source.spectrum.main.Cutoff_powerlaw.xc             (6.9 +/- 0.4) x 10
# cons_nustar_fpma                                         1.46 +/- 0.10
# cons_nustar_fpmb                                         1.47 +/- 0.11
#
#                                                        unit
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
# source.spectrum.main.Cutoff_powerlaw.index
# source.spectrum.main.Cutoff_powerlaw.xc                 keV
# cons_nustar_fpma
# cons_nustar_fpmb
# Correlation matrix:
#  1.00 -0.40  0.24 -0.65 -0.65
# -0.40  1.00 -0.77 -0.40 -0.40
#  0.24 -0.77  1.00  0.24  0.24
# -0.65 -0.40  0.24  1.00  0.99
# -0.65 -0.40  0.24  0.99  1.00
# Values of -log(likelihood) at the minimum:
#              -log(likelihood)
# nustar_fpma       3332.445853
# nustar_fpmb       3461.106070
# total             6793.551923
# Values of statistical measures:
#      statistical measures
# AIC          13597.124212
# BIC          13627.055037
# (                                                value  negative_error  \
#  source.spectrum.main.Cutoff_powerlaw.K       0.026545       -0.001791
#  source.spectrum.main.Cutoff_powerlaw.index  -1.319120       -0.022543
#  source.spectrum.main.Cutoff_powerlaw.xc     68.820370       -3.880948
#  cons_nustar_fpma                             1.455836       -0.107001
#  cons_nustar_fpmb                             1.473701       -0.106338
#
#                                              positive_error     error  \
#  source.spectrum.main.Cutoff_powerlaw.K            0.001961  0.001876
#  source.spectrum.main.Cutoff_powerlaw.index        0.022528  0.022536
#  source.spectrum.main.Cutoff_powerlaw.xc           4.037915  3.959432
#  cons_nustar_fpma                                  0.102200  0.104600
#  cons_nustar_fpmb                                  0.103294  0.104816
#
#                                                         unit
#  source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
#  source.spectrum.main.Cutoff_powerlaw.index
#  source.spectrum.main.Cutoff_powerlaw.xc                 keV
#  cons_nustar_fpma
#  cons_nustar_fpmb                                             ,
#               -log(likelihood)
#  nustar_fpma       3332.445853
#  nustar_fpmb       3461.106070
#  total             6793.551923)

# %%
plot_spectra(jl_no_eac_nustar.results, flux_unit="erg2/(keV s cm2)")
# Out:
# processing MLE analyses:   0%|          | 0/1 [00:00<?, ?it/s]
# Propagating errors:   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# # COSI Analysis

# %% [markdown]
# Create BinnedData objects for the NGC4151_ec200 only, NGC4151_ec200+background, and background only. The NGC4151_ec200 only simulation is not used for the spectral fit, but can be used to compare the fitted spectrum to the source simulation

# %%
NGC4151_ec200 = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec200.yaml')
NGC4151_ec200_bkg = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec200.yaml')
bkg = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/background.yaml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 NGC1068_ec200 = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec200.yaml')
#       2 NGC1068_ec200_bkg = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec200.yaml')
#       3 bkg = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/background.yaml')
#
# NameError: name 'BinnedData' is not defined

# %% [markdown]
# Load binned .hdf5 files

# %%
# NGC4151_ec200 = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec200_COSI_sourceInj_correctFlux_hist.hdf5")
# bkg = Histogram.open(data_path / "DC2_Files/bkg_binned_data.hdf5").slice[:, 1:, :, :]
# NGC4151_ec200_bkg = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec200_bkg_hist.hdf5").slice[1:, :, :]

NGC4151_ec200 = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec200_COSI_sourceInj_correctFlux_hist.hdf5")
bkg = Histogram.open(data_path / "DC2_Files/bkg_binned_data.hdf5")
NGC4151_ec200_bkg = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec200_bkg_hist.hdf5")

fig, ax = plt.subplots(figsize=(12, 9))
NGC4151_ec200.project("Em").draw(ax, label="NGC4151 w/ 200 keV cutoff", color="green")
bkg.project("Em").draw(ax, label="Binned Continuum Background", color="orange", linestyle="dashed")
NGC4151_ec200_bkg.project("Em").draw(ax, label="NGC4151 w/ 200keV cutoff + Background", linestyle='dashdot', color="blue")

ax.set_yscale("log")
ax.set_xscale("log")

# ax.set_ylim(1e0, 1e8)
ax.set_ylabel("Counts")
ax.set_xlabel("Energy")
plt.legend()

# %% [markdown]
# Define the path to the detector response

# %% [markdown]
# ## Perform spectral fit

# %% [markdown]
# Set background parameter, which is used to fit the amplitude of the background, and instantiate the COSI 3ML plugin

# %%
bkg_par = Parameter("background_cosi",                                         # background parameter
                     1,                                                        # initial value of parameter
                     min_value=0,                                              # minimum value of parameter
                     max_value=5,                                              # maximum value of parameter
                     delta=0.05,                                               # initial step used by fitting engine
                     desc="Background parameter for cosi")

cosi = COSILike("cosi",                                                        # COSI 3ML plugin
                 dr = dr,                                                      # detector response
                 data = NGC4151_ec200_bkg.project('Em', 'Phi', 'PsiChi'),   # data (source+background)
                 bkg = bkg.project('Em', 'Phi', 'PsiChi'),         # background model 
                 sc_orientation = sc_orientation,                              # spacecraft orientation
                 nuisance_param = bkg_par,                                     # background parameter
                 earth_occ = True)                                             # Option to account for Earth occultation

# %% [markdown]
# Define a point source at the known location with a Band function spectrum and add it to the model. The initial values of the Band function parameters are set to the true values used to simulate the source

# %% [markdown]
# ### Powerlaw with energy cutoff fit

# %%
l=155.07
b=75.06

# Give it some harsher initial guesses
K = 0.1 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
xc = 10. * u.keV
index = -2.5

spectrum = Cutoff_powerlaw()

spectrum.K.value = K.value
spectrum.piv.value = piv.value
spectrum.xc.value = xc.value
spectrum.index.value = index

# #Working parameters
# spectrum.K.min_value = 0.10
# spectrum.K.max_value = 0.17
# spectrum.xc.min_value = 180
# spectrum.xc.max_value = 210
# spectrum.index.min_value = -2.
# spectrum.index.max_value = -1.60

# Harsher Parameters
spectrum.K.min_value = 1e-4
spectrum.K.max_value = 1
spectrum.xc.min_value = 1 # keep these relatively the same
spectrum.xc.max_value = 10000 # change to 1000
spectrum.index.min_value = -3 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum.index.max_value = 1

spectrum.K.delta = 0.05
spectrum.xc.delta = 10
spectrum.index.delta = 0.25

spectrum.K.unit = K.unit
spectrum.piv.unit = piv.unit
spectrum.xc.unit = xc.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum(energy_grid)))
# ax.loglog(energy_grid, spectrum(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = l,                        # Longitude (deg)
                     b = b,                        # Latitude (deg)
                     spectral_shape = spectrum)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model = Model(source)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# # Optional: if you want to call get_log_like manually, then you also need to set the model manually
# # 3ML does this internally during the fit though
cosi.set_model(model)

# %% [markdown]
# ### Simple Powerlaw fit

# %%
l=155.07
b=75.06

# Give it some harsher initial guesses
K = 5 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
# xc = 1000. * u.keV
index = -2

spectrum = Powerlaw()

spectrum.K.value = K.value
spectrum.piv.value = piv.value
# spectrum.xc.value = xc.value
spectrum.index.value = index

# #Working parameters
# spectrum.K.min_value = 0.10
# spectrum.K.max_value = 0.17
# spectrum.xc.min_value = 180
# spectrum.xc.max_value = 210
# spectrum.index.min_value = -2.
# spectrum.index.max_value = -1.60

# # Harsher Parameters
spectrum.K.min_value = 1
spectrum.K.max_value = 12
# spectrum.xc.min_value = 800 # keep these relatively the same
# spectrum.xc.max_value = 1200
spectrum.index.min_value = -3.5 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum.index.max_value = 1

spectrum.K.delta = 0.1
# # spectrum.xc.delta = 0.0001
spectrum.index.delta = 5e-1

spectrum.K.unit = K.unit
spectrum.piv.unit = piv.unit
# spectrum.xc.unit = xc.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum(energy_grid)))
# ax.loglog(energy_grid, spectrum(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = l,                        # Longitude (deg)
                     b = b,                        # Latitude (deg)
                     spectral_shape = spectrum)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model = Model(source)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# # Optional: if you want to call get_log_like manually, then you also need to set the model manually
# # 3ML does this internally during the fit though
cosi.set_model(model)

# %% [markdown]
# Gather all plugins and combine with the model in a JointLikelihood object, then perform maximum likelihood fit

# %%
# bat.use_effective_area_correction(0.2, 1.8)
# plugins = DataList(bat, cosi) # If we had multiple instruments, we would do e.g. DataList(cosi, lat, hawc, ...)
nustar_fpma.use_effective_area_correction(0.2, 1.8)
nustar_fpmb.use_effective_area_correction(0.2, 1.8)
plugins = DataList(cosi, nustar_fpma, nustar_fpmb)
# plugins = DataList(cosi, bat, nustar_fpma, nustar_fpmb)
# plugins = DataList(cosi) # If we had multiple instruments, we would do e.g. DataList(cosi, lat, hawc, ...)

like = JointLikelihood(model, plugins, verbose = False)

like.fit() #increase number of samples?
# Out:
# 09:48:02 INFO      nustar_fpma is using effective area correction (between 0.2 and 1.8)        ]8;id=315035;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=701072;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#2279\2279]8;;\
#          INFO      nustar_fpmb is using effective area correction (between 0.2 and 1.8)        ]8;id=44995;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=377104;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#2279\2279]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=659743;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=993110;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py#1046\1046]8;;\
# Adding 1e-12 to each bin of the expectation to avoid log-likelihood = -inf.
# Best fit values:
#                                                                result  \
# parameter
# source.spectrum.main.Cutoff_powerlaw.K        (8.4 -1.0 +1.1) x 10^-2
# source.spectrum.main.Cutoff_powerlaw.index           -1.625 +/- 0.033
# source.spectrum.main.Cutoff_powerlaw.xc     (1.76 -0.12 +0.13) x 10^2
# background_cosi                                   1.00007 +/- 0.00016
# cons_nustar_fpma                                (9.9 +/- 0.4) x 10^-1
# cons_nustar_fpmb                                        1.00 +/- 0.04
#
#                                                        unit
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
# source.spectrum.main.Cutoff_powerlaw.index
# source.spectrum.main.Cutoff_powerlaw.xc                 keV
# background_cosi
# cons_nustar_fpma
# cons_nustar_fpmb
# Correlation matrix:
#  1.00 -0.93  0.50 -0.13 -0.64 -0.64
# -0.93  1.00 -0.78  0.21  0.31  0.31
#  0.50 -0.78  1.00 -0.35  0.30  0.30
# -0.13  0.21 -0.35  1.00 -0.08 -0.08
# -0.64  0.31  0.30 -0.08  1.00  0.96
# -0.64  0.31  0.30 -0.08  0.96  1.00
# Values of -log(likelihood) at the minimum:
#              -log(likelihood)
# cosi            -2.262965e+08
# nustar_fpma      3.334432e+03
# nustar_fpmb      3.463320e+03
# total           -2.262897e+08
# Values of statistical measures:
#      statistical measures
# AIC         -4.525795e+08
# BIC         -4.525794e+08
# (                                                 value  negative_error  \
#  source.spectrum.main.Cutoff_powerlaw.K        0.083592       -0.009871
#  source.spectrum.main.Cutoff_powerlaw.index   -1.625146       -0.034387
#  source.spectrum.main.Cutoff_powerlaw.xc     175.669490      -11.679434
#  background_cosi                               1.000071       -0.000159
#  cons_nustar_fpma                              0.988533       -0.042591
#  cons_nustar_fpmb                              1.000803       -0.042488
#
#                                              positive_error      error  \
#  source.spectrum.main.Cutoff_powerlaw.K            0.011353   0.010612
#  source.spectrum.main.Cutoff_powerlaw.index        0.032762   0.033575
#  source.spectrum.main.Cutoff_powerlaw.xc          13.066056  12.372745
#  background_cosi                                   0.000163   0.000161
#  cons_nustar_fpma                                  0.043029   0.042810
#  cons_nustar_fpmb                                  0.043347   0.042917
#
#                                                         unit
#  source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
#  source.spectrum.main.Cutoff_powerlaw.index
#  source.spectrum.main.Cutoff_powerlaw.xc                 keV
#  background_cosi
#  cons_nustar_fpma
#  cons_nustar_fpmb                                             ,
#               -log(likelihood)
#  cosi            -2.262965e+08
#  nustar_fpma      3.334432e+03
#  nustar_fpmb      3.463320e+03
#  total           -2.262897e+08)

# %% [markdown]
# ## Error propagation and plotting (Cutoff powerlaw function)

# %% [markdown]
# Define Band function spectrum injected into MEGAlib

# %%
K_inj = 0.15 / u.cm / u.cm / u.s / u.keV
piv_inj = 1. * u.keV
xc_inj = 200. * u.keV
index_inj = -1.75

spectrum_inj = Cutoff_powerlaw()

spectrum_inj.K.value = K_inj.value
spectrum_inj.piv.value = piv_inj.value
spectrum_inj.xc.value = xc_inj.value
spectrum_inj.index.value = index_inj

spectrum_inj.K.unit = K_inj.unit
spectrum_inj.piv.unit = piv_inj.unit
spectrum_inj.xc.unit = xc_inj.unit

# %% [markdown]
# The summary of the results above tell you the optimal values of the parameters, as well as the errors. Propogate the errors to the "evaluate_at" method of the spectrum

# %%
results = like.results

print(results.display())

parameters = {par.name:results.get_variates(par.path)
              for par in results.optimized_model["source"].parameters.values()
              if par.free}

results_err = results.propagate(results.optimized_model["source"].spectrum.main.shape.evaluate_at, **parameters)

print(results.optimized_model["source"])
# Out:
# Best fit values:
#                                                                result  \
# parameter
# source.spectrum.main.Cutoff_powerlaw.K        (8.4 -1.0 +1.1) x 10^-2
# source.spectrum.main.Cutoff_powerlaw.index           -1.625 +/- 0.033
# source.spectrum.main.Cutoff_powerlaw.xc     (1.76 -0.12 +0.13) x 10^2
# background_cosi                                   1.00007 +/- 0.00016
# cons_nustar_fpma                                (9.9 +/- 0.4) x 10^-1
# cons_nustar_fpmb                                        1.00 +/- 0.04
#
#                                                        unit
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
# source.spectrum.main.Cutoff_powerlaw.index
# source.spectrum.main.Cutoff_powerlaw.xc                 keV
# background_cosi
# cons_nustar_fpma
# cons_nustar_fpmb
# Correlation matrix:
#  1.00 -0.93  0.50 -0.13 -0.64 -0.64
# -0.93  1.00 -0.78  0.21  0.31  0.31
#  0.50 -0.78  1.00 -0.35  0.30  0.30
# -0.13  0.21 -0.35  1.00 -0.08 -0.08
# -0.64  0.31  0.30 -0.08  1.00  0.96
# -0.64  0.31  0.30 -0.08  0.96  1.00
# Values of -log(likelihood) at the minimum:
#              -log(likelihood)
# cosi            -2.262965e+08
# nustar_fpma      3.334432e+03
# nustar_fpmb      3.463320e+03
# total           -2.262897e+08
# Values of statistical measures:
#      statistical measures
# AIC         -4.525795e+08
# BIC         -4.525794e+08
# None
#   * source (point source):
#     * position:
#       * l:
#         * value: 155.07
#         * desc: Galactic longitude
#         * min_value: 0.0
#         * max_value: 360.0
#         * unit: deg
#         * is_normalization: false
#       * b:
#         * value: 75.06
#         * desc: Galactic latitude
#         * min_value: -90.0
#         * max_value: 90.0
#         * unit: deg
#         * is_normalization: false
#       * equinox: J2000
#     * spectrum:
#       * main:
#         * Cutoff_powerlaw:
#           * K:
#             * value: 0.08359204917960228
#             * desc: Normalization (differential flux at the pivot value)
#             * min_value: 0.0001
#             * max_value: 1.0
#             * unit: keV-1 s-1 cm-2
#             * is_normalization: true
#           * piv:
#             * value: 1.0
#             * desc: Pivot value
#             * min_value: null
#             * max_value: null
#             * unit: keV
#             * is_normalization: false
#           * index:
#             * value: -1.6251463139055713
#             * desc: Photon index
#             * min_value: -3.0
#             * max_value: 1.0
#             * unit: ''
#             * is_normalization: false
#           * xc:
#             * value: 175.669490243062
#             * desc: Cutoff energy
#             * min_value: 1.0
#             * max_value: 10000.0
#             * unit: keV
#             * is_normalization: false
#         * polarization: {}

# %% [markdown]
# Evaluate the flux and errors at a range of energies for the fitted and injected spectra, and the simulated source flux

# %%
energy = np.geomspace(20*u.keV,10*u.MeV).to_value(u.keV)

flux_lo = np.zeros_like(energy)
flux_median = np.zeros_like(energy)
flux_hi = np.zeros_like(energy)
flux_inj = np.zeros_like(energy)

for i, e in enumerate(energy):
    flux = results_err(e)
    flux_median[i] = flux.median
    flux_lo[i], flux_hi[i] = flux.equal_tail_interval(cl=0.68)
    flux_inj[i] = spectrum_inj.evaluate_at(e)
    
binned_energy_edges = NGC4151_ec200.axes['Em'].edges.value
# print(binned_energy_edges)
binned_energy = np.array([])
bin_sizes = np.array([])

for i in range(len(binned_energy_edges)-1):
    binned_energy = np.append(binned_energy, (binned_energy_edges[i+1] + binned_energy_edges[i]) / 2)
    bin_sizes = np.append(bin_sizes, binned_energy_edges[i+1] - binned_energy_edges[i])

expectation = cosi._expected_counts['source']

# %% [markdown]
# Plot the fitted and injected spectra

# %%
fig,ax = plt.subplots()

ax.plot(energy, energy*energy*flux_median, label = "Best fit")
ax.fill_between(energy, energy*energy*flux_lo, energy*energy*flux_hi, alpha = .5, label = "Best fit (errors)")
ax.plot(energy, energy*energy*flux_inj, color = 'black', ls = ":", label = "Injected")

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel(r"$E^2 \frac{dN}{dE}$ (keV cm$^{-2}$ s$^{-1}$)")

# ax.set_ylim(1e-3, 1)

ax.legend()

# %% [markdown]
# Plot the fitted spectrum convolved with the response, as well as the simulated source counts

# %%
fig,ax = plt.subplots()

ax.stairs(expectation.project('Em').todense().contents, binned_energy_edges, color='purple', label = "Best fit convolved with response")
ax.errorbar(binned_energy, expectation.project('Em').todense().contents, yerr=np.sqrt(expectation.project('Em').todense().contents), color='purple', linewidth=0, elinewidth=1)
ax.stairs(NGC4151_ec200.project('Em').todense().contents, binned_energy_edges, color = 'black', ls = ":", label = "Source counts")
ax.errorbar(binned_energy, NGC4151_ec200.project('Em').todense().contents, yerr=np.sqrt(NGC4151_ec200.project('Em').todense().contents), color='black', linewidth=0, elinewidth=1)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Counts")

ax.legend()

# %% [markdown]
# Plot the fitted spectrum convolved with the response plus the fitted background, as well as the simulated source+background counts

# %%
fig,ax = plt.subplots()

ax.stairs(expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents), binned_energy_edges, color='purple', label = "Best fit convolved with response plus background")
ax.errorbar(binned_energy, expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents), yerr=np.sqrt(expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents)), color='purple', linewidth=0, elinewidth=1)
ax.stairs(NGC4151_ec200_bkg.project('Em').todense().contents, binned_energy_edges, color = 'black', ls = ":", label = "Total counts")
ax.errorbar(binned_energy, NGC4151_ec200_bkg.project('Em').todense().contents, yerr=np.sqrt(NGC4151_ec200_bkg.project('Em').todense().contents), color='black', linewidth=0, elinewidth=1)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Counts")

ax.legend()

# %% [markdown]
# # NGC 4151 with 1000 keV cutoff.

# %%
NGC4151_ec1000 = BinnedData("/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec1000.yaml")
NGC4151_ec1000_bkg = BinnedData("/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec1000.yaml")
bkg = BinnedData("/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/background.yaml")

# %%
NGC4151_ec1000 = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec1000_COSI_sourceInj_correctFlux_hist.hdf5")
bkg = Histogram.open(data_path / "DC2_Files/bkg_binned_data.hdf5")
NGC4151_ec1000_bkg = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec1000_bkg_hist.hdf5")
NGC4151_ec200 = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec200_COSI_sourceInj_correctFlux_hist.hdf5")

fig, ax = plt.subplots(figsize=(12, 9))
NGC4151_ec1000.project("Em").draw(ax, label="NGC4151 w/ 1000 keV cutoff", color="green")
NGC4151_ec200.project("Em").draw(ax, label="NGC4151 w/ 200 keV cutoff", color="black")
bkg.project("Em").draw(ax, label="Binned Continuum Background", color="orange", linestyle="dashed")
NGC4151_ec1000_bkg.project("Em").draw(ax, label="NGC4151 w/ 1000keV cutoff + Background", linestyle='dashdot', color="blue")

ax.set_yscale("log")
ax.set_xscale("log")

# ax.set_ylim(1e0, 1e8)
ax.set_ylabel("Counts")
plt.legend()

# %%
bkg_par = Parameter("background_cosi",                                         # background parameter
                     1,                                                        # initial value of parameter
                     min_value=0,                                              # minimum value of parameter
                     max_value=5,                                              # maximum value of parameter
                     delta=0.05,                                               # initial step used by fitting engine
                     desc="Background parameter for cosi")

cosi = COSILike("cosi",                                                        # COSI 3ML plugin
                 dr = dr,                                                      # detector response
                 data = NGC4151_ec1000_bkg.project('Em', 'Phi', 'PsiChi'),   # data (source+background)
                 bkg = bkg.project('Em', 'Phi', 'PsiChi'),         # background model 
                 sc_orientation = sc_orientation,                              # spacecraft orientation
                 nuisance_param = bkg_par,                                     # background parameter
                 earth_occ = True)                                             # Option to account for Earth occultation

# %%
l=155.07
b=75.06

# Give it some harsher initial guesses
K = 0.1 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
xc = 100. * u.keV
index = -1.75

spectrum = Cutoff_powerlaw()

spectrum.K.value = K.value
spectrum.piv.value = piv.value
spectrum.xc.value = xc.value
spectrum.index.value = index

# #Working parameters
# spectrum.K.fix = True
# spectrum.index.fix = True

# Harsher Parameters
spectrum.K.min_value = 1e-4
spectrum.K.max_value = 1
spectrum.xc.min_value = 100 # keep these relatively the same
spectrum.xc.max_value = 10000 # change to 1000
spectrum.index.min_value = -3 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum.index.max_value = 1

spectrum.K.delta = 0.05
spectrum.xc.delta = 10
spectrum.index.delta = 0.15

spectrum.K.unit = K.unit
spectrum.piv.unit = piv.unit
spectrum.xc.unit = xc.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum(energy_grid)))
# ax.loglog(energy_grid, spectrum(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = l,                        # Longitude (deg)
                     b = b,                        # Latitude (deg)
                     spectral_shape = spectrum)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model = Model(source)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# # Optional: if you want to call get_log_like manually, then you also need to set the model manually
# # 3ML does this internally during the fit though
cosi.set_model(model)

# %%
l=155.07
b=75.06

# Give it some harsher initial guesses
K = 1e-1 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
# xc = 1000. * u.keV
index = -1

spectrum = Powerlaw()

spectrum.K.value = K.value
spectrum.piv.value = piv.value
# spectrum.xc.value = xc.value
spectrum.index.value = index

# # Harsher Parameters
spectrum.K.min_value = 1
spectrum.K.max_value = 12
# spectrum.xc.min_value = 800 # keep these relatively the same
# spectrum.xc.max_value = 1200
spectrum.index.min_value = -3.5 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum.index.max_value = 2

spectrum.K.delta = 0.1
# # spectrum.xc.delta = 0.0001
spectrum.index.delta = 5e-1

spectrum.K.unit = K.unit
spectrum.piv.unit = piv.unit
# spectrum.xc.unit = xc.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum(energy_grid)))
# ax.loglog(energy_grid, spectrum(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = l,                        # Longitude (deg)
                     b = b,                        # Latitude (deg)
                     spectral_shape = spectrum)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model = Model(source)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# # Optional: if you want to call get_log_like manually, then you also need to set the model manually
# # 3ML does this internally during the fit though
cosi.set_model(model)

# %%
nustar_fpma.use_effective_area_correction(0.1, 1.8)
nustar_fpmb.use_effective_area_correction(0.1, 1.8)
# plugins = DataList(bat, cosi)
plugins = DataList(nustar_fpma, nustar_fpmb, cosi)
# plugins = DataList(cosi) # If we had multiple instruments, we would do e.g. DataList(cosi, lat, hawc, ...)

like = JointLikelihood(model, plugins, verbose = False)

like.fit() #increase number of samples?
# Out:
# 15:45:47 INFO      nustar_fpma is using effective area correction (between 0.2 and 1.8)        ]8;id=651309;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=477843;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#2279\2279]8;;\
#          INFO      nustar_fpmb is using effective area correction (between 0.2 and 1.8)        ]8;id=111324;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=357033;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#2279\2279]8;;\
# 15:45:48 INFO      set the minimizer to minuit                                             ]8;id=704522;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=136867;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py#1046\1046]8;;\
# Adding 1e-12 to each bin of the expectation to avoid log-likelihood = -inf.
# Best fit values:
#                                                                 result  \
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      (1.54 -0.19 +0.22) x 10^-1
# source.spectrum.main.Cutoff_powerlaw.index            -1.786 +/- 0.029
# source.spectrum.main.Cutoff_powerlaw.xc      (1.10 -0.12 +0.14) x 10^3
# cons_nustar_fpma                               (7.98 +/- 0.34) x 10^-1
# cons_nustar_fpmb                               (8.07 +/- 0.34) x 10^-1
# background_cosi                                    1.00016 +/- 0.00019
#
#                                                        unit
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
# source.spectrum.main.Cutoff_powerlaw.index
# source.spectrum.main.Cutoff_powerlaw.xc                 keV
# cons_nustar_fpma
# cons_nustar_fpmb
# background_cosi
# Correlation matrix:
#  1.00 -0.99  0.78 -0.96 -0.96 -0.18
# -0.99  1.00 -0.84  0.92  0.92  0.21
#  0.78 -0.84  1.00 -0.62 -0.62 -0.45
# -0.96  0.92 -0.62  1.00  0.96  0.12
# -0.96  0.92 -0.62  0.96  1.00  0.12
# -0.18  0.21 -0.45  0.12  0.12  1.00
# Values of -log(likelihood) at the minimum:
#              -log(likelihood)
# nustar_fpma      3.337396e+03
# nustar_fpmb      3.466256e+03
# cosi            -2.280369e+08
# total           -2.280301e+08
# Values of statistical measures:
#      statistical measures
# AIC         -4.560601e+08
# BIC         -4.560601e+08
# (                                                  value  negative_error  \
#  source.spectrum.main.Cutoff_powerlaw.K         0.153613       -0.018589
#  source.spectrum.main.Cutoff_powerlaw.index    -1.785541       -0.028283
#  source.spectrum.main.Cutoff_powerlaw.xc     1100.451599     -122.687889
#  cons_nustar_fpma                               0.797562       -0.032965
#  cons_nustar_fpmb                               0.807397       -0.034176
#  background_cosi                                1.000159       -0.000197
#
#                                              positive_error       error  \
#  source.spectrum.main.Cutoff_powerlaw.K            0.021432    0.020011
#  source.spectrum.main.Cutoff_powerlaw.index        0.027951    0.028117
#  source.spectrum.main.Cutoff_powerlaw.xc         141.641374  132.164632
#  cons_nustar_fpma                                  0.032709    0.032837
#  cons_nustar_fpmb                                  0.033284    0.033730
#  background_cosi                                   0.000188    0.000193
#
#                                                         unit
#  source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
#  source.spectrum.main.Cutoff_powerlaw.index
#  source.spectrum.main.Cutoff_powerlaw.xc                 keV
#  cons_nustar_fpma
#  cons_nustar_fpmb
#  background_cosi                                              ,
#               -log(likelihood)
#  nustar_fpma      3.337396e+03
#  nustar_fpmb      3.466256e+03
#  cosi            -2.280369e+08
#  total           -2.280301e+08)

# %%
K_inj = 0.15 / u.cm / u.cm / u.s / u.keV
piv_inj = 1. * u.keV
xc_inj = 1000. * u.keV
index_inj = -1.75

spectrum_inj = Cutoff_powerlaw()

spectrum_inj.K.value = K_inj.value
spectrum_inj.piv.value = piv_inj.value
spectrum_inj.xc.value = xc_inj.value
spectrum_inj.index.value = index_inj

spectrum_inj.K.unit = K_inj.unit
spectrum_inj.piv.unit = piv_inj.unit
spectrum_inj.xc.unit = xc_inj.unit

# %%
results = like.results

print(results.display())

parameters = {par.name:results.get_variates(par.path)
              for par in results.optimized_model["source"].parameters.values()
              if par.free}

results_err = results.propagate(results.optimized_model["source"].spectrum.main.shape.evaluate_at, **parameters)

print(results.optimized_model["source"])
# Out:
# Best fit values:
#                                                                 result  \
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      (1.54 -0.19 +0.22) x 10^-1
# source.spectrum.main.Cutoff_powerlaw.index            -1.786 +/- 0.029
# source.spectrum.main.Cutoff_powerlaw.xc      (1.10 -0.12 +0.14) x 10^3
# cons_nustar_fpma                               (7.98 +/- 0.34) x 10^-1
# cons_nustar_fpmb                               (8.07 +/- 0.34) x 10^-1
# background_cosi                                    1.00016 +/- 0.00019
#
#                                                        unit
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
# source.spectrum.main.Cutoff_powerlaw.index
# source.spectrum.main.Cutoff_powerlaw.xc                 keV
# cons_nustar_fpma
# cons_nustar_fpmb
# background_cosi
# Correlation matrix:
#  1.00 -0.99  0.78 -0.96 -0.96 -0.18
# -0.99  1.00 -0.84  0.92  0.92  0.21
#  0.78 -0.84  1.00 -0.62 -0.62 -0.45
# -0.96  0.92 -0.62  1.00  0.96  0.12
# -0.96  0.92 -0.62  0.96  1.00  0.12
# -0.18  0.21 -0.45  0.12  0.12  1.00
# Values of -log(likelihood) at the minimum:
#              -log(likelihood)
# nustar_fpma      3.337396e+03
# nustar_fpmb      3.466256e+03
# cosi            -2.280369e+08
# total           -2.280301e+08
# Values of statistical measures:
#      statistical measures
# AIC         -4.560601e+08
# BIC         -4.560601e+08
# None
#   * source (point source):
#     * position:
#       * l:
#         * value: 155.07
#         * desc: Galactic longitude
#         * min_value: 0.0
#         * max_value: 360.0
#         * unit: deg
#         * is_normalization: false
#       * b:
#         * value: 75.06
#         * desc: Galactic latitude
#         * min_value: -90.0
#         * max_value: 90.0
#         * unit: deg
#         * is_normalization: false
#       * equinox: J2000
#     * spectrum:
#       * main:
#         * Cutoff_powerlaw:
#           * K:
#             * value: 0.15361256368751142
#             * desc: Normalization (differential flux at the pivot value)
#             * min_value: 0.0001
#             * max_value: 1.0
#             * unit: keV-1 s-1 cm-2
#             * is_normalization: true
#           * piv:
#             * value: 1.0
#             * desc: Pivot value
#             * min_value: null
#             * max_value: null
#             * unit: keV
#             * is_normalization: false
#           * index:
#             * value: -1.785541223033039
#             * desc: Photon index
#             * min_value: -3.0
#             * max_value: 1.0
#             * unit: ''
#             * is_normalization: false
#           * xc:
#             * value: 1100.4515991169371
#             * desc: Cutoff energy
#             * min_value: 100.0
#             * max_value: 10000.0
#             * unit: keV
#             * is_normalization: false
#         * polarization: {}

# %%
energy = np.geomspace(20*u.keV,10*u.MeV).to_value(u.keV)

flux_lo = np.zeros_like(energy)
flux_median = np.zeros_like(energy)
flux_hi = np.zeros_like(energy)
flux_inj = np.zeros_like(energy)

for i, e in enumerate(energy):
    flux = results_err(e)
    flux_median[i] = flux.median
    flux_lo[i], flux_hi[i] = flux.equal_tail_interval(cl=0.68)
    flux_inj[i] = spectrum_inj.evaluate_at(e)
    
binned_energy_edges = NGC4151_ec200.axes['Em'].edges.value
# print(binned_energy_edges)
binned_energy = np.array([])
bin_sizes = np.array([])

for i in range(len(binned_energy_edges)-1):
    binned_energy = np.append(binned_energy, (binned_energy_edges[i+1] + binned_energy_edges[i]) / 2)
    bin_sizes = np.append(bin_sizes, binned_energy_edges[i+1] - binned_energy_edges[i])

expectation = cosi._expected_counts['source']

# %%
fig,ax = plt.subplots()

ax.plot(energy, energy*energy*flux_median, label = "Best fit")
ax.fill_between(energy, energy*energy*flux_lo, energy*energy*flux_hi, alpha = .5, label = "Best fit (errors)")
ax.plot(energy, energy*energy*flux_inj, color = 'black', ls = ":", label = "Injected")

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel(r"$E^2 \frac{dN}{dE}$ (keV cm$^{-2}$ s$^{-1}$)")

ax.legend()

# %%
fig,ax = plt.subplots()

ax.stairs(expectation.project('Em').todense().contents, binned_energy_edges, color='purple', label = "Best fit convolved with response")
ax.errorbar(binned_energy, expectation.project('Em').todense().contents, yerr=np.sqrt(expectation.project('Em').todense().contents), color='purple', linewidth=0, elinewidth=1)
ax.stairs(NGC4151_ec1000.project('Em').todense().contents, binned_energy_edges, color = 'black', ls = ":", label = "Source counts")
ax.errorbar(binned_energy, NGC4151_ec1000.project('Em').todense().contents, yerr=np.sqrt(NGC4151_ec1000.project('Em').todense().contents), color='black', linewidth=0, elinewidth=1)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Counts")

ax.legend()

# %%
fig,ax = plt.subplots()

ax.stairs(expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents), binned_energy_edges, color='purple', label = "Best fit convolved with response plus background")
ax.errorbar(binned_energy, expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents), yerr=np.sqrt(expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents)), color='purple', linewidth=0, elinewidth=1)
ax.stairs(NGC4151_ec1000_bkg.project('Em').todense().contents, binned_energy_edges, color = 'black', ls = ":", label = "Total counts")
ax.errorbar(binned_energy, NGC4151_ec1000_bkg.project('Em').todense().contents, yerr=np.sqrt(NGC4151_ec1000_bkg.project('Em').todense().contents), color='black', linewidth=0, elinewidth=1)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Counts")

ax.legend()

# %% [markdown]
# # NGC 1068 200 keV Cutoff

# %% [markdown]
# Create BinnedData objects for the NGC1068_ec200 only, NGC1068_ec200+background, and background only. The NGC4151_ec200 only simulation is not used for the spectral fit, but can be used to compare the fitted spectrum to the source simulation

# %%
NGC1068_ec200 = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec200.yaml')
NGC1068_ec200_bkg = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/NGC4151_ec200.yaml')
bkg = BinnedData('/Users/parshadkp/Software/COSI_Data/AGN_Data/GammaRay/background.yaml')

# %% [markdown]
# Load binned .hdf5 files

# %%
# NGC1068_ec200 = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec200_COSI_sourceInj_correctFlux_hist.hdf5")
# bkg = Histogram.open(data_path / "DC2_Files/bkg_binned_data.hdf5").slice[:, 1:, :, :]
# NGC1068_ec200_bkg = Histogram.open("/Users/parshadkp/Library/CloudStorage/OneDrive-ClemsonUniversity/COSI/AGN_Coronae/SourceInj/NGC_4151_ec200_bkg_hist.hdf5").slice[1:, :, :]

NGC1068_ec200 = Histogram.open(data_path/"AGN_Data/GammaRay/NGC_1068_ec200_corrected_COSI.hdf5")
bkg = Histogram.open(data_path / "DC2_Files/bkg_binned_data.hdf5")
NGC1068_ec200_bkg = Histogram.open(data_path / "AGN_Data/GammaRay/NGC_1068_ec200_bkg_COSI.hdf5")

fig, ax = plt.subplots(figsize=(12, 9))
NGC1068_ec200.project("Em").draw(ax, label="NGC1068 w/ 200 keV cutoff", color="green")
bkg.project("Em").draw(ax, label="Binned Continuum Background", color="orange", linestyle="dashed")
NGC1068_ec200_bkg.project("Em").draw(ax, label="NGC1068 w/ 200keV cutoff + Background", linestyle='dashdot', color="blue")

ax.set_yscale("log")
ax.set_xscale("log")

# ax.set_ylim(1e0, 1e8)
ax.set_ylabel("Counts")
ax.set_xlabel("Energy")
plt.legend()

# %% [markdown]
# Define the path to the detector response

# %% [markdown]
# ## Perform spectral fit

# %% [markdown]
# Set background parameter, which is used to fit the amplitude of the background, and instantiate the COSI 3ML plugin

# %%
bkg_par = Parameter("background_cosi",                                         # background parameter
                     1,                                                        # initial value of parameter
                     min_value=0,                                              # minimum value of parameter
                     max_value=5,                                              # maximum value of parameter
                     delta=0.05,                                               # initial step used by fitting engine
                     desc="Background parameter for cosi")

cosi = COSILike("cosi",                                                        # COSI 3ML plugin
                 dr = dr,                                                      # detector response
                 data = NGC1068_ec200_bkg.project('Em', 'Phi', 'PsiChi'),   # data (source+background)
                 bkg = bkg.project('Em', 'Phi', 'PsiChi'),         # background model 
                 sc_orientation = sc_orientation,                              # spacecraft orientation
                 nuisance_param = bkg_par,                                     # background parameter
                 earth_occ = True)                                             # Option to account for Earth occultation

# %% [markdown]
# Define a point source at the known location with a Band function spectrum and add it to the model. The initial values of the Band function parameters are set to the true values used to simulate the source

# %% [markdown]
# ### Powerlaw with energy cutoff fit

# %%
l=17.2
b=-51.9

# Give it some harsher initial guesses
K = 0.1 / u.cm / u.cm / u.s / u.keV
piv = 1. * u.keV
xc = 10. * u.keV
index = -2.5

spectrum = Cutoff_powerlaw()

spectrum.K.value = K.value
spectrum.piv.value = piv.value
spectrum.xc.value = xc.value
spectrum.index.value = index

# #Working parameters
# spectrum.K.min_value = 0.10
# spectrum.K.max_value = 0.17
# spectrum.xc.min_value = 180
# spectrum.xc.max_value = 210
# spectrum.index.min_value = -2.
# spectrum.index.max_value = -1.60

# Harsher Parameters
spectrum.K.min_value = 1e-4
spectrum.K.max_value = 1
spectrum.xc.min_value = 1 # keep these relatively the same
spectrum.xc.max_value = 10000 # change to 1000
spectrum.index.min_value = -3 # change to -3.5 to sample lower, larger values (-5, 5)
spectrum.index.max_value = 1

spectrum.K.delta = 0.05
spectrum.xc.delta = 10
spectrum.index.delta = 0.25

spectrum.K.unit = K.unit
spectrum.piv.unit = piv.unit
spectrum.xc.unit = xc.unit

# fig, ax = plt.subplots()

# energy_grid = np.logspace(2, 4, 10000000)

# # ax.loglog(energy_grid, (energy_grid**2)*(spectrum(energy_grid)))
# ax.loglog(energy_grid, spectrum(energy_grid))
# ax.set_xlabel("energy [keV]")
# ax.set_ylim(1e-17, 1e-3)
# ax.set_ylabel(f"flux [{K.unit}]")

source = PointSource("source",                     # Name of source (arbitrary, but needs to be unique)
                     l = l,                        # Longitude (deg)
                     b = b,                        # Latitude (deg)
                     spectral_shape = spectrum)    # Spectral model

# # Optional: free the position parameters
# #source.position.l.free = True
# #source.position.b.free = True

model = Model(source)  # Model with single source. If we had multiple sources, we would do Model(source1, source2, ...)

# # Optional: if you want to call get_log_like manually, then you also need to set the model manually
# # 3ML does this internally during the fit though
cosi.set_model(model)

# %% [markdown]
# Gather all plugins and combine with the model in a JointLikelihood object, then perform maximum likelihood fit

# %%
# bat.use_effective_area_correction(0.2, 1.8)
# plugins = DataList(bat, cosi) # If we had multiple instruments, we would do e.g. DataList(cosi, lat, hawc, ...)
nustar_fpma.use_effective_area_correction(0.2, 1.8)
nustar_fpmb.use_effective_area_correction(0.2, 1.8)
plugins = DataList(cosi, nustar_fpma, nustar_fpmb)
# plugins = DataList(cosi, bat, nustar_fpma, nustar_fpmb)
# plugins = DataList(cosi) # If we had multiple instruments, we would do e.g. DataList(cosi, lat, hawc, ...)

like = JointLikelihood(model, plugins, verbose = False)

like.fit() #increase number of samples?
# Out:
# 20:58:46 INFO      nustar_fpma is using effective area correction (between 0.2 and 1.8)        ]8;id=853934;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=409081;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#2279\2279]8;;\
#          INFO      nustar_fpmb is using effective area correction (between 0.2 and 1.8)        ]8;id=712996;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=326737;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/plugins/SpectrumLike.py#2279\2279]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=932596;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=125585;file:///Users/parshadkp/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py#1046\1046]8;;\
# Adding 1e-12 to each bin of the expectation to avoid log-likelihood = -inf.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 11
#       6 # plugins = DataList(cosi, bat, nustar_fpma, nustar_fpmb)
#       7 # plugins = DataList(cosi) # If we had multiple instruments, we would do e.g. DataList(cosi, lat, hawc, ...)
#       9 like = JointLikelihood(model, plugins, verbose = False)
# ---> 11 like.fit() #increase number of samples?
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py:327, in JointLikelihood.fit(self, quiet, compute_covariance, n_samples)
#     323 # Perform the fit, but first flush stdout (so if we have verbose=True the messages there will follow
#     324 # what is already in the buffer)
#     325 sys.stdout.flush()
# --> 327 xs, log_likelihood_minimum = self._minimizer.minimize(
#     328     compute_covar=compute_covariance
#     329 )
#     331 if log_likelihood_minimum == minimization.FIT_FAILED:
#     332     log.error("The fit failed to converge.")
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minimization.py:632, in Minimizer.minimize(self, compute_covar)
#     628 # Gather the best fit values from the minimizer and the covariance matrix (if provided)
#     630 try:
# --> 632     internal_best_fit_values, function_minimum = self._minimize()
#     634 except FitFailed:
#     636     raise
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/minimizer/minuit_minimizer.py:204, in MinuitMinimizer._minimize(self)
#     199         break
#     201     else:
#     202
#     203         # Try again
# --> 204         self._last_migrad_results = self.minuit.migrad()
#     206 if not self.minuit.valid:
#     208     self._print_current_status()
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/iminuit/minuit.py:789, in Minuit.migrad(self, ncall, iterate, use_simplex)
#     787 t = mutil._Timer(self._fmin)
#     788 with t:
# --> 789     fm = _robust_low_level_fit(
#     790         self._fcn,
#     791         self._last_state,
#     792         replace_none(ncall, 0),
#     793         self._strategy,
#     794         self._tolerance,
#     795         self._precision,
#     796         iterate,
#     797         use_simplex,
#     798     )
#     800 self._last_state = fm.state
#     802 self._fmin = mutil.FMin(
#     803     fm,
#     804     "Migrad",
#    (...)
#     809     t.value,
#     810 )
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/iminuit/minuit.py:2797, in _robust_low_level_fit(fcn, state, ncall, strategy, tolerance, precision, iterate, use_simplex)
#    2795     if precision is not None:
#    2796         migrad.precision = precision
# -> 2797     fm = migrad(ncall, tolerance)
#    2798     iterate -= 1
#    2799 return fm
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/threeML/classicMLE/joint_likelihood.py:980, in JointLikelihood.minus_log_like_profile(self, *trial_values)
#     976 for dataset in list(self._data_list.values()):
#     978     try:
# --> 980         this_log_like = dataset.inner_fit()
#     982     except ModelAssertionViolation:
#     983
#     984         # This is a zone of the parameter space which is not allowed. Return
#     985         # a big number for the likelihood so that the fit engine will avoid it
#     987         log.warning(
#     988             "Fitting engine in forbidden space: %s" % (trial_values,),
#     989         )
#
# File ~/Software/cosipy/cosipy/threeml/COSILike.py:305, in COSILike.inner_fit(self)
#     300 def inner_fit(self):
#     301     """
#     302     Required for 3ML fit.
#     303     """
# --> 305     return self.get_log_like()
#
# File ~/Software/cosipy/cosipy/threeml/COSILike.py:270, in COSILike.get_log_like(self)
#     267     log.error("You need to set the model first")
#     269 # Set model:
# --> 270 self.set_model(self._model)
#     272 # Compute expectation including free background parameter:
#     273 if self._fit_nuisance_params:
#
# File ~/Software/cosipy/cosipy/threeml/COSILike.py:132, in COSILike.set_model(self, model)
#     122 """
#     123 Set the model to be used in the joint minimization.
#     124
#    (...)
#     128     Any model supported by astromodels
#     129 """
#     131 # Temporary fix to only print log-likelihood warning once max per fit
# --> 132 if inspect.stack()[1][3] == '_assign_model_to_data':
#     133     self._printed_warning = False
#     135 # Get point sources and extended sources from model:
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/inspect.py:1676, in stack(context)
#    1674 def stack(context=1):
#    1675     """Return a list of records for the stack above the caller's frame."""
# -> 1676     return getouterframes(sys._getframe(1), context)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/inspect.py:1653, in getouterframes(frame, context)
#    1651 framelist = []
#    1652 while frame:
# -> 1653     frameinfo = (frame,) + getframeinfo(frame, context)
#    1654     framelist.append(FrameInfo(*frameinfo))
#    1655     frame = frame.f_back
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/inspect.py:1627, in getframeinfo(frame, context)
#    1625 start = lineno - 1 - context//2
#    1626 try:
# -> 1627     lines, lnum = findsource(frame)
#    1628 except OSError:
#    1629     lines = index = None
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/inspect.py:952, in findsource(object)
#     949     if not (file.startswith('<') and file.endswith('>')):
#     950         raise OSError('source code not available')
# --> 952 module = getmodule(object, file)
#     953 if module:
#     954     lines = linecache.getlines(file, module.__dict__)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/inspect.py:869, in getmodule(object, _filename)
#     866 # Update the filename to module name cache and check yet again
#     867 # Copy sys.modules in order to cope with changes while iterating
#     868 for modname, module in sys.modules.copy().items():
# --> 869     if ismodule(module) and hasattr(module, '__file__'):
#     870         f = module.__file__
#     871         if f == _filesbymodname.get(modname, None):
#     872             # Have already mapped this module, so skip it
#
# KeyboardInterrupt:

# %% [markdown]
# ## Error propagation and plotting (Cutoff powerlaw function)

# %% [markdown]
# Define Band function spectrum injected into MEGAlib

# %%
K_inj = 5e-1 / u.cm / u.cm / u.s / u.keV
piv_inj = 1. * u.keV
xc_inj = 200. * u.keV
index_inj = -1.92

spectrum_inj = Cutoff_powerlaw()

spectrum_inj.K.value = K_inj.value
spectrum_inj.piv.value = piv_inj.value
spectrum_inj.xc.value = xc_inj.value
spectrum_inj.index.value = index_inj

spectrum_inj.K.unit = K_inj.unit
spectrum_inj.piv.unit = piv_inj.unit
spectrum_inj.xc.unit = xc_inj.unit

# %% [markdown]
# The summary of the results above tell you the optimal values of the parameters, as well as the errors. Propogate the errors to the "evaluate_at" method of the spectrum

# %%
results = like.results

print(results.display())

parameters = {par.name:results.get_variates(par.path)
              for par in results.optimized_model["source"].parameters.values()
              if par.free}

results_err = results.propagate(results.optimized_model["source"].spectrum.main.shape.evaluate_at, **parameters)

print(results.optimized_model["source"])
# Out:
# Best fit values:
#                                                              result  \
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      (7.30 +/- 0.22) x 10^-2
# source.spectrum.main.Cutoff_powerlaw.index         -1.638 +/- 0.009
# source.spectrum.main.Cutoff_powerlaw.xc      (1.60 +/- 0.05) x 10^2
# cons_BAT                                    (6.91 +/- 0.14) x 10^-1
# background_cosi                                 1.00011 +/- 0.00015
#
#                                                        unit
# parameter
# source.spectrum.main.Cutoff_powerlaw.K      1 / (keV s cm2)
# source.spectrum.main.Cutoff_powerlaw.index
# source.spectrum.main.Cutoff_powerlaw.xc                 keV
# cons_BAT
# background_cosi
# Correlation matrix:
#  1.00 -0.66  0.16 -0.39 -0.08
# -0.66  1.00 -0.76 -0.40  0.05
#  0.16 -0.76  1.00  0.60 -0.15
# -0.39 -0.40  0.60  1.00  0.10
# -0.08  0.05 -0.15  0.10  1.00
# Values of -log(likelihood) at the minimum:
#        -log(likelihood)
# BAT        1.876314e+00
# cosi      -2.261463e+08
# total     -2.261463e+08
# Values of statistical measures:
#      statistical measures
# AIC          0.000000e+00
# BIC         -4.522926e+08
# None
#   * source (point source):
#     * position:
#       * l:
#         * value: 17.2
#         * desc: Galactic longitude
#         * min_value: 0.0
#         * max_value: 360.0
#         * unit: deg
#         * is_normalization: false
#       * b:
#         * value: -51.9
#         * desc: Galactic latitude
#         * min_value: -90.0
#         * max_value: 90.0
#         * unit: deg
#         * is_normalization: false
#       * equinox: J2000
#     * spectrum:
#       * main:
#         * Cutoff_powerlaw:
#           * K:
#             * value: 0.0730013891668053
#             * desc: Normalization (differential flux at the pivot value)
#             * min_value: 0.0001
#             * max_value: 1.0
#             * unit: keV-1 s-1 cm-2
#             * is_normalization: true
#           * piv:
#             * value: 1.0
#             * desc: Pivot value
#             * min_value: null
#             * max_value: null
#             * unit: keV
#             * is_normalization: false
#           * index:
#             * value: -1.6381691032079773
#             * desc: Photon index
#             * min_value: -3.0
#             * max_value: 1.0
#             * unit: ''
#             * is_normalization: false
#           * xc:
#             * value: 159.59277155108362
#             * desc: Cutoff energy
#             * min_value: 1.0
#             * max_value: 10000.0
#             * unit: keV
#             * is_normalization: false
#         * polarization: {}

# %% [markdown]
# Evaluate the flux and errors at a range of energies for the fitted and injected spectra, and the simulated source flux

# %%
energy = np.geomspace(40*u.keV,10*u.MeV).to_value(u.keV)

flux_lo = np.zeros_like(energy)
flux_median = np.zeros_like(energy)
flux_hi = np.zeros_like(energy)
flux_inj = np.zeros_like(energy)

for i, e in enumerate(energy):
    flux = results_err(e)
    flux_median[i] = flux.median
    flux_lo[i], flux_hi[i] = flux.equal_tail_interval(cl=0.68)
    flux_inj[i] = spectrum_inj.evaluate_at(e)
    
binned_energy_edges = NGC1068_ec200.axes['Em'].edges.value
# print(binned_energy_edges)
binned_energy = np.array([])
bin_sizes = np.array([])

for i in range(len(binned_energy_edges)-1):
    binned_energy = np.append(binned_energy, (binned_energy_edges[i+1] + binned_energy_edges[i]) / 2)
    bin_sizes = np.append(bin_sizes, binned_energy_edges[i+1] - binned_energy_edges[i])

expectation = cosi._expected_counts['source']

# %% [markdown]
# Plot the fitted and injected spectra

# %%
fig,ax = plt.subplots()

ax.plot(energy, energy*energy*flux_median, label = "Best fit")
ax.fill_between(energy, energy*energy*flux_lo, energy*energy*flux_hi, alpha = .5, label = "Best fit (errors)")
ax.plot(energy, energy*energy*flux_inj, color = 'black', ls = ":", label = "Injected")

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel(r"$E^2 \frac{dN}{dE}$ (keV cm$^{-2}$ s$^{-1}$)")

# ax.set_ylim(1e-3, 1)

ax.legend()

# %% [markdown]
# Plot the fitted spectrum convolved with the response, as well as the simulated source counts

# %%
fig,ax = plt.subplots()

ax.stairs(expectation.project('Em').todense().contents, binned_energy_edges, color='purple', label = "Best fit convolved with response")
ax.errorbar(binned_energy, expectation.project('Em').todense().contents, yerr=np.sqrt(expectation.project('Em').todense().contents), color='purple', linewidth=0, elinewidth=1)
ax.stairs(NGC1068_ec200.project('Em').todense().contents, binned_energy_edges, color = 'black', ls = ":", label = "Source counts")
ax.errorbar(binned_energy, NGC1068_ec200.project('Em').todense().contents, yerr=np.sqrt(NGC1068_ec200.project('Em').todense().contents), color='black', linewidth=0, elinewidth=1)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Counts")

ax.legend()

# %% [markdown]
# Plot the fitted spectrum convolved with the response plus the fitted background, as well as the simulated source+background counts

# %%
fig,ax = plt.subplots()

ax.stairs(expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents), binned_energy_edges, color='purple', label = "Best fit convolved with response plus background")
ax.errorbar(binned_energy, expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents), yerr=np.sqrt(expectation.project('Em').todense().contents+(bkg_par.value * bkg.project('Em').todense().contents)), color='purple', linewidth=0, elinewidth=1)
ax.stairs(NGC1068_ec200_bkg.project('Em').todense().contents, binned_energy_edges, color = 'black', ls = ":", label = "Total counts")
ax.errorbar(binned_energy, NGC1068_ec200_bkg.project('Em').todense().contents, yerr=np.sqrt(NGC1068_ec200_bkg.project('Em').todense().contents), color='black', linewidth=0, elinewidth=1)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Counts")

ax.legend()
